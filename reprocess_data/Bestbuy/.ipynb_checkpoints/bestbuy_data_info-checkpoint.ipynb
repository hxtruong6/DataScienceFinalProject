# %% [markdown]
# # Preprocessing Bestbuy data

# %% [markdown]
# ## Import library

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from pandas.plotting import register_matplotlib_converters
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read data

# %%
df = pd.read_csv("../../dataset/BestBuy/product_infos.csv", encoding='utf-8', sep='\t')
df.head(10)
# Out:
#                             Price__Price Key Specs__Backlit Keyboard  \
# 0    Your price for this item is $119.00                          No
# 1    Your price for this item is $279.99                          No
# 2    Your price for this item is $349.99                          No
# 3    Your price for this item is $349.00                         Yes
# 4    Your price for this item is $499.99                         Yes
# 5    Your price for this item is $749.99                         Yes
# 6    Your price for this item is $449.99                         Yes
# 7    Your price for this item is $129.99                          No
# 8    Your price for this item is $579.99                         Yes
# 9  Your price for this item is $1,099.99                         Yes
#
#   Key Specs__Screen Size Key Specs__Touch Screen Key Specs__Storage Type  \
# 0            11.6 inches                      No                    eMMC
# 1            15.6 inches                     Yes                     SSD
# 2            15.6 inches                     Yes                     SSD
# 3              14 inches                     Yes                    eMMC
# 4              14 inches                     Yes                     SSD
# 5            15.6 inches                     Yes                     SSD
# 6            15.6 inches                      No                     SSD
# 7              14 inches                      No                    eMMC
# 8            15.6 inches                      No                     SSD
# 9            15.6 inches                     Yes                     SSD
#
#   Key Specs__Total Storage Capacity Key Specs__eMMC Capacity  \
# 0                      32 gigabytes             32 gigabytes
# 1                     128 gigabytes                      NaN
# 2                     256 gigabytes                      NaN
# 3                      64 gigabytes             64 gigabytes
# 4                     256 gigabytes                      NaN
# 5                     512 gigabytes                      NaN
# 6                     256 gigabytes                      NaN
# 7                      64 gigabytes             64 gigabytes
# 8                     512 gigabytes                      NaN
# 9                     512 gigabytes                      NaN
#
#   Key Specs__System Memory (RAM)      Key Specs__Graphics  \
# 0                    4 gigabytes                     None
# 1                    8 gigabytes   Intel UHD Graphics 620
# 2                    8 gigabytes   Intel UHD Graphics 620
# 3                    8 gigabytes   Intel UHD Graphics 620
# 4                    8 gigabytes                     None
# 5                   12 gigabytes                     None
# 6                    8 gigabytes  NVIDIA GeForce GTX 1050
# 7                    4 gigabytes            AMD Radeon R4
# 8                    8 gigabytes  NVIDIA GeForce GTX 1650
# 9                   16 gigabytes     NVIDIA GeForce MX250
#
#   Key Specs__Processor Speed (Base)  ... Camera__Front-Facing Camera  \
# 0                    1.04 gigahertz  ...                         NaN
# 1                     2.1 gigahertz  ...                         NaN
# 2                     1.6 gigahertz  ...                         NaN
# 3                     2.2 gigahertz  ...                         NaN
# 4                     1.6 gigahertz  ...                         NaN
# 5                     1.8 gigahertz  ...                         NaN
# 6                     2.1 gigahertz  ...                         NaN
# 7                     1.6 gigahertz  ...                         NaN
# 8                     2.4 gigahertz  ...                         NaN
# 9                     1.8 gigahertz  ...                         NaN
#
#   Camera__Front Facing Camera Megapixels  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
#
#   Camera__Front Facing Camera Video Resolution Performance__Battery Life  \
# 0                                          NaN                       NaN
# 1                                          NaN                       NaN
# 2                                          NaN                       NaN
# 3                                          NaN                       NaN
# 4                                          NaN                       NaN
# 5                                          NaN                       NaN
# 6                                          NaN                       NaN
# 7                                          NaN                       NaN
# 8                                          NaN                       NaN
# 9                                          NaN                       NaN
#
#   Performance__System Memory (RAM) Performance__Processor Brand  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# 5                              NaN                          NaN
# 6                              NaN                          NaN
# 7                              NaN                          NaN
# 8                              NaN                          NaN
# 9                              NaN                          NaN
#
#   Performance__Processor Model Expansion__Number of M.2 Slots  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
# 5                          NaN                            NaN
# 6                          NaN                            NaN
# 7                          NaN                            NaN
# 8                          NaN                            NaN
# 9                          NaN                            NaN
#
#   Expansion__Number Of Internal 2.5" Bays Expansion__Number Of eSATA Ports
# 0                                     NaN                              NaN
# 1                                     NaN                              NaN
# 2                                     NaN                              NaN
# 3                                     NaN                              NaN
# 4                                     NaN                              NaN
# 5                                     NaN                              NaN
# 6                                     NaN                              NaN
# 7                                     NaN                              NaN
# 8                                     NaN                              NaN
# 9                                     NaN                              NaN
#
# [10 rows x 168 columns]

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041 entries, 0 to 1040
# Data columns (total 168 columns):
# Price__Price                                        1041 non-null object
# Key Specs__Backlit Keyboard                         1026 non-null object
# Key Specs__Screen Size                              1041 non-null object
# Key Specs__Touch Screen                             1032 non-null object
# Key Specs__Storage Type                             1025 non-null object
# Key Specs__Total Storage Capacity                   987 non-null object
# Key Specs__eMMC Capacity                            125 non-null object
# Key Specs__System Memory (RAM)                      1032 non-null object
# Key Specs__Graphics                                 1012 non-null object
# Key Specs__Processor Speed (Base)                   1002 non-null object
# Key Specs__Processor Model                          1041 non-null object
# Key Specs__Processor Model Number                   1002 non-null object
# Key Specs__Operating System                         1027 non-null object
# Key Specs__Battery Type                             1041 non-null object
# Key Specs__Solid State Drive Capacity               773 non-null object
# Key Specs__2-in-1 Design                            264 non-null object
# Key Specs__Battery Life                             423 non-null object
# Key Specs__Voice Assistant Built-in                 29 non-null object
# Key Specs__Hard Drive Capacity                      194 non-null object
# Key Specs__Security Features                        7 non-null object
# Key Specs__Screen Resolution                        9 non-null object
# Key Specs__Internet Connectivity                    9 non-null object
# Key Specs__Works With                               36 non-null object
# General__Product Name                               1039 non-null object
# General__Brand                                      1039 non-null object
# General__Model Number                               1041 non-null object
# General__Color                                      987 non-null object
# General__Color Category                             1041 non-null object
# General__Casing Material                            352 non-null object
# General__Year Introduced                            130 non-null object
# General__Data Plan Required                         7 non-null object
# General__Model Family                               9 non-null object
# General__Year of Release                            8 non-null float64
# Feature__Keyboard Touch Screen                      792 non-null object
# Feature__Backlit Keyboard                           1026 non-null object
# Feature__Cooling System                             957 non-null object
# Feature__Operating System Architecture              578 non-null object
# Feature__Chrome Features                            20 non-null object
# Feature__2-in-1 Design                              264 non-null object
# Feature__Touchpad Type                              440 non-null object
# Feature__Security Features                          360 non-null object
# Feature__Mac Features                               71 non-null object
# Feature__Ultrabook                                  80 non-null object
# Feature__Total Storage Capacity                     9 non-null object
# Feature__GPS Enabled                                7 non-null object
# Feature__Keyboard Included                          5 non-null object
# Feature__Stylus Dock                                112 non-null object
# Feature__Wake Word                                  6 non-null object
# Feature__Customizable Case Lighting                 17 non-null object
# Feature__Windows Features                           102 non-null object
# Feature__Cable Lock Slot                            156 non-null object
# Feature__Customizable Keyboard Lighting             54 non-null object
# Feature__Rugged Design                              52 non-null object
# Ports__Headphone Jack                               887 non-null object
# Ports__Number of USB Ports (Total)                  936 non-null float64
# Ports__Number of USB 2.0 Type A Ports               265 non-null float64
# Ports__Number of USB 3.0 Type A Ports               714 non-null float64
# Ports__Number of HDMI Outputs (Total)               686 non-null float64
# Ports__Number of USB 3.1 Type C Ports               518 non-null float64
# Ports__Number of USB Type C Charging Ports          34 non-null float64
# Ports__Number of USB 3.1 Type A Ports               111 non-null float64
# Ports__Number of Thunderbolt Ports (Total)          267 non-null float64
# Ports__Number of Thunderbolt 3 Ports                257 non-null float64
# Ports__Number of USB 3.0 Type C Ports               22 non-null float64
# Ports__Number of USB 2.0 Type C Ports               2 non-null float64
# Ports__Number of Thunderbolt 2 Ports                17 non-null float64
# Ports__Number of VGA Ports                          151 non-null float64
# Ports__Number Of IEEE 1394 Ports                    53 non-null float64
# Ports__Number of DisplayPort Outputs (Total)        106 non-null float64
# Ports__Number of DisplayPort Ver. 1.4 Outputs       6 non-null float64
# Ports__Number of HDMI HDCP 2.2 Outputs              3 non-null float64
# Ports__Number of DisplayPort Ver. 1.2 Outputs       16 non-null float64
# Ports__Number of USB Type A Charging Ports          47 non-null float64
# Ports__Number of DisplayPort Ver. 1.3 Outputs       1 non-null float64
# Display__Screen Size                                1041 non-null object
# Display__Screen Resolution                          1039 non-null object
# Display__Touch Screen                               1032 non-null object
# Display__Display Type                               1038 non-null object
# Display__Screen Type                                6 non-null object
# Display__High Dynamic Range (HDR)                   6 non-null object
# Display__Stylus Input                               52 non-null object
# Display__Wireless Display                           44 non-null object
# Storage__Storage Type                               1025 non-null object
# Storage__Total Storage Capacity                     978 non-null object
# Storage__eMMC Capacity                              125 non-null object
# Storage__Hard Drive Accelerator                     739 non-null object
# Storage__Solid State Drive Capacity                 773 non-null object
# Storage__Solid State Drive Interface                358 non-null object
# Storage__Hard Drive Capacity                        194 non-null object
# Storage__Hard Drive Interface                       119 non-null object
# Storage__Hard Drive RPM                             90 non-null object
# Memory__System Memory (RAM)                         1032 non-null object
# Memory__Type of Memory (RAM)                        1032 non-null object
# Memory__System Memory RAM Speed                     691 non-null object
# Memory__Cache Memory                                798 non-null object
# Memory__Media Card Reader                           734 non-null object
# Memory__System Memory RAM Expandable To             470 non-null object
# Memory__Number Of Memory Slots                      453 non-null float64
# Memory__Number of Memory Sticks Included            293 non-null float64
# Graphics__Graphics                                  1012 non-null object
# Graphics__Graphics Type                             1031 non-null object
# Graphics__Video Memory Type                         354 non-null object
# Graphics__GPU Brand                                 503 non-null object
# Graphics__Video Memory                              348 non-null object
# Processor__Processor Brand                          1032 non-null object
# Processor__Processor Speed (Base)                   1002 non-null object
# Processor__Processor Model                          1032 non-null object
# Processor__Processor Model Number                   1002 non-null object
# Connectivity__Internet Connectivity                 921 non-null object
# Connectivity__Bluetooth Enabled                     932 non-null object
# Connectivity__Embedded Mobile Broadband             837 non-null object
# Connectivity__NFC Enabled                           854 non-null object
# Connectivity__Compatible Wireless Standard(s)       9 non-null object
# Connectivity__Bluetooth Version                     8 non-null float64
# Connectivity__Headphone Jack                        9 non-null object
# Connectivity__Interface(s)                          9 non-null object
# Network__Wireless Networking                        976 non-null object
# Network__Ethernet                                   541 non-null object
# Network__Ethernet Card                              563 non-null object
# Network__Number Of Ethernet Ports                   509 non-null float64
# Network__Carrier                                    1 non-null object
# Compatibility__Operating System                     1027 non-null object
# Compatibility__Voice Assistant Built-in             29 non-null object
# Compatibility__Operating System Compatibility       9 non-null object
# Compatibility__Expandable Memory Compatibility      9 non-null object
# Compatibility__Works With                           36 non-null object
# Compatibility__Virtual Reality Compatibility        11 non-null object
# Included__Built-In Webcam                           1032 non-null object
# Included__Optical Drive Type                        1004 non-null object
# Included__Additional Accessories Included           906 non-null object
# Included__Included Software                         372 non-null object
# Included__Numeric Keypad                            472 non-null object
# Included__Stylus Included                           143 non-null object
# Included__Blu-Ray Player                            192 non-null object
# Power__Battery Type                                 1041 non-null object
# Power__Battery Cells                                616 non-null object
# Power__Battery Life                                 423 non-null object
# Power__Charging Interface(s)                        9 non-null object
# Power__Battery Capacity                             77 non-null object
# Power__Charging Interface Generation/Version        3 non-null float64
# Dimension__Product Height                           1008 non-null object
# Dimension__Product Width                            1008 non-null object
# Dimension__Product Depth                            1008 non-null object
# Dimension__Product Weight                           989 non-null object
# Audio__Speaker Type                                 922 non-null object
# Audio__Audio Technology                             494 non-null object
# Certifications & Listings__ENERGY STAR Certified    1039 non-null object
# Certifications & Listings__EPEAT Qualified          1032 non-null object
# Certifications & Listings__EPEAT Level              183 non-null object
# Warranty__Manufacturer's Warranty - Parts           1041 non-null object
# Warranty__Manufacturer's Warranty - Labor           1041 non-null object
# Other__UPC                                          1041 non-null int64
# Other__Internal Carrier                             1 non-null object
# Other__Product Name                                 2 non-null object
# Other__Brand                                        2 non-null object
# Camera__Rear-Facing Camera                          9 non-null object
# Camera__Rear Facing Camera Megapixels               8 non-null object
# Camera__Rear Facing Camera Video Resolution         8 non-null object
# Camera__Front-Facing Camera                         9 non-null object
# Camera__Front Facing Camera Megapixels              9 non-null object
# Camera__Front Facing Camera Video Resolution        6 non-null object
# Performance__Battery Life                           6 non-null object
# Performance__System Memory (RAM)                    9 non-null object
# Performance__Processor Brand                        9 non-null object
# Performance__Processor Model                        9 non-null object
# Expansion__Number of M.2 Slots                      45 non-null float64
# Expansion__Number Of Internal 2.5" Bays             42 non-null float64
# Expansion__Number Of eSATA Ports                    7 non-null float64
# dtypes: float64(29), int64(1), object(138)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Preprocessing data

# %% [markdown]
# ### 1. Drop column has many NaN value
#
# Columns has many NaN value which will make wrong desition prediction.

# %%
df.isna().sum()
# Out:
# Price__Price                                  0
# Key Specs__Backlit Keyboard                  15
# Key Specs__Screen Size                        0
# Key Specs__Touch Screen                       9
# Key Specs__Storage Type                      16
#                                            ...
# Performance__Processor Brand               1032
# Performance__Processor Model               1032
# Expansion__Number of M.2 Slots              996
# Expansion__Number Of Internal 2.5" Bays     999
# Expansion__Number Of eSATA Ports           1034
# Length: 168, dtype: int64

# %%
df.isna().sum().describe()
# Out:
# count     168.000000
# mean      582.172619
# std       433.547392
# min         0.000000
# 25%        48.750000
# 50%       691.000000
# 75%      1024.000000
# max      1040.000000
# dtype: float64

# %% [markdown]
# Bestbuy data just has 1041 rows.
#
# Drop all columns has larger MAX_NAN_COUNT Nan value
#
# *Note*: MAX_NAN_COUNT is just the selected number.

# %%
MAX_NAN_COUNT = 48

# %%
drop_cols_name = [col for col in df.columns if df[col].isna().sum() > MAX_NAN_COUNT]
drop_cols_name
# for i in drop_cols_name:
#     print(df[i].isna().sum())
# Out:
# ['Key Specs__Total Storage Capacity',
#  'Key Specs__eMMC Capacity',
#  'Key Specs__Solid State Drive Capacity',
#  'Key Specs__2-in-1 Design',
#  'Key Specs__Battery Life',
#  'Key Specs__Voice Assistant Built-in',
#  'Key Specs__Hard Drive Capacity',
#  'Key Specs__Security Features',
#  'Key Specs__Screen Resolution',
#  'Key Specs__Internet Connectivity',
#  'Key Specs__Works With',
#  'General__Color',
#  'General__Casing Material',
#  'General__Year Introduced',
#  'General__Data Plan Required',
#  'General__Model Family',
#  'General__Year of Release',
#  'Feature__Keyboard Touch Screen',
#  'Feature__Cooling System',
#  'Feature__Operating System Architecture',
#  'Feature__Chrome Features',
#  'Feature__2-in-1 Design',
#  'Feature__Touchpad Type',
#  'Feature__Security Features',
#  'Feature__Mac Features',
#  'Feature__Ultrabook',
#  'Feature__Total Storage Capacity',
#  'Feature__GPS Enabled',
#  'Feature__Keyboard Included',
#  'Feature__Stylus Dock',
#  'Feature__Wake Word',
#  'Feature__Customizable Case Lighting',
#  'Feature__Windows Features',
#  'Feature__Cable Lock Slot',
#  'Feature__Customizable Keyboard Lighting',
#  'Feature__Rugged Design',
#  'Ports__Headphone Jack',
#  'Ports__Number of USB Ports (Total)',
#  'Ports__Number of USB 2.0 Type A Ports',
#  'Ports__Number of USB 3.0 Type A Ports',
#  'Ports__Number of HDMI Outputs (Total)',
#  'Ports__Number of USB 3.1 Type C Ports',
#  'Ports__Number of USB Type C Charging Ports',
#  'Ports__Number of USB 3.1 Type A Ports',
#  'Ports__Number of Thunderbolt Ports (Total)',
#  'Ports__Number of Thunderbolt 3 Ports',
#  'Ports__Number of USB 3.0 Type C Ports',
#  'Ports__Number of USB 2.0 Type C Ports',
#  'Ports__Number of Thunderbolt 2 Ports',
#  'Ports__Number of VGA Ports',
#  'Ports__Number Of IEEE 1394 Ports',
#  'Ports__Number of DisplayPort Outputs (Total)',
#  'Ports__Number of DisplayPort Ver. 1.4 Outputs',
#  'Ports__Number of HDMI HDCP 2.2 Outputs',
#  'Ports__Number of DisplayPort Ver. 1.2 Outputs',
#  'Ports__Number of USB Type A Charging Ports',
#  'Ports__Number of DisplayPort Ver. 1.3 Outputs',
#  'Display__Screen Type',
#  'Display__High Dynamic Range (HDR)',
#  'Display__Stylus Input',
#  'Display__Wireless Display',
#  'Storage__Total Storage Capacity',
#  'Storage__eMMC Capacity',
#  'Storage__Hard Drive Accelerator',
#  'Storage__Solid State Drive Capacity',
#  'Storage__Solid State Drive Interface',
#  'Storage__Hard Drive Capacity',
#  'Storage__Hard Drive Interface',
#  'Storage__Hard Drive RPM',
#  'Memory__System Memory RAM Speed',
#  'Memory__Cache Memory',
#  'Memory__Media Card Reader',
#  'Memory__System Memory RAM Expandable To',
#  'Memory__Number Of Memory Slots',
#  'Memory__Number of Memory Sticks Included',
#  'Graphics__Video Memory Type',
#  'Graphics__GPU Brand',
#  'Graphics__Video Memory',
#  'Connectivity__Internet Connectivity',
#  'Connectivity__Bluetooth Enabled',
#  'Connectivity__Embedded Mobile Broadband',
#  'Connectivity__NFC Enabled',
#  'Connectivity__Compatible Wireless Standard(s)',
#  'Connectivity__Bluetooth Version',
#  'Connectivity__Headphone Jack',
#  'Connectivity__Interface(s)',
#  'Network__Wireless Networking',
#  'Network__Ethernet',
#  'Network__Ethernet Card',
#  'Network__Number Of Ethernet Ports',
#  'Network__Carrier',
#  'Compatibility__Voice Assistant Built-in',
#  'Compatibility__Operating System Compatibility',
#  'Compatibility__Expandable Memory Compatibility',
#  'Compatibility__Works With',
#  'Compatibility__Virtual Reality Compatibility',
#  'Included__Additional Accessories Included',
#  'Included__Included Software',
#  'Included__Numeric Keypad',
#  'Included__Stylus Included',
#  'Included__Blu-Ray Player',
#  'Power__Battery Cells',
#  'Power__Battery Life',
#  'Power__Charging Interface(s)',
#  'Power__Battery Capacity',
#  'Power__Charging Interface Generation/Version',
#  'Dimension__Product Weight',
#  'Audio__Speaker Type',
#  'Audio__Audio Technology',
#  'Certifications & Listings__EPEAT Level',
#  'Other__Internal Carrier',
#  'Other__Product Name',
#  'Other__Brand',
#  'Camera__Rear-Facing Camera',
#  'Camera__Rear Facing Camera Megapixels',
#  'Camera__Rear Facing Camera Video Resolution',
#  'Camera__Front-Facing Camera',
#  'Camera__Front Facing Camera Megapixels',
#  'Camera__Front Facing Camera Video Resolution',
#  'Performance__Battery Life',
#  'Performance__System Memory (RAM)',
#  'Performance__Processor Brand',
#  'Performance__Processor Model',
#  'Expansion__Number of M.2 Slots',
#  'Expansion__Number Of Internal 2.5" Bays',
#  'Expansion__Number Of eSATA Ports']

# %%
df.drop(columns=drop_cols_name, axis=1, inplace=True)

# %% [markdown]
# ### 2. Get Price

# %%
df.sample(5)
# Out:
#                               Price__Price Key Specs__Backlit Keyboard  \
# 955    Your price for this item is $267.99                          No
# 422  Your price for this item is $1,449.99                         Yes
# 31      Your price for this item is $89.00                          No
# 170    Your price for this item is $269.99                          No
# 91     Your price for this item is $759.99                          No
#
#     Key Specs__Screen Size Key Specs__Touch Screen Key Specs__Storage Type  \
# 955            12.5 inches                      No                     SSD
# 422            15.6 inches                      No                     SSD
# 31             11.6 inches                      No                    eMMC
# 170              14 inches                     Yes                    eMMC
# 91             17.3 inches                      No                     HDD
#
#     Key Specs__System Memory (RAM)      Key Specs__Graphics  \
# 955                    8 gigabytes        Intel HD Graphics
# 422                   16 gigabytes  NVIDIA GeForce RTX 2060
# 31                     2 gigabytes                     None
# 170                    4 gigabytes                    Other
# 91                    16 gigabytes                    Other
#
#     Key Specs__Processor Speed (Base)     Key Specs__Processor Model  \
# 955                     1.9 gigahertz   Intel 4th Generation Core i5
# 422                     2.6 gigahertz   Intel 9th Generation Core i7
# 31                     1.04 gigahertz                     Intel Atom
# 170                     1.5 gigahertz                         AMD A4
# 91                      1.3 gigahertz  Intel 10th Generation Core i7
#
#     Key Specs__Processor Model Number  ... Included__Optical Drive Type  \
# 955                          i5-4300U  ...                         None
# 422                          i7-9750H  ...                         None
# 31                              E8000  ...                         None
# 170                          A4-9120e  ...                         None
# 91                          i7-1065G7  ...                       DVD-RW
#
#     Power__Battery Type Dimension__Product Height Dimension__Product Width  \
# 955         Lithium-ion                       NaN                      NaN
# 422     Lithium-polymer                0.7 inches              14.1 inches
# 31          Lithium-ion                0.7 inches              11.4 inches
# 170         Lithium-ion                0.7 inches              13.3 inches
# 91          Lithium-ion                  1 inches              16.4 inches
#
#     Dimension__Product Depth Certifications & Listings__ENERGY STAR Certified  \
# 955                      NaN                                               No
# 422                10 inches                                               No
# 31                8.1 inches                                              Yes
# 170               8.9 inches                                              Yes
# 91                 11 inches                                               No
#
#     Certifications & Listings__EPEAT Qualified  \
# 955                                         No
# 422                                         No
# 31                                          No
# 170                                         No
# 91                                          No
#
#     Warranty__Manufacturer's Warranty - Parts  \
# 955                                 18 months
# 422                                   2 years
# 31                                     1 year
# 170                                    1 year
# 91                                     1 year
#
#     Warranty__Manufacturer's Warranty - Labor    Other__UPC
# 955                                 18 months  841631129407
# 422                                   2 years  193199253651
# 31                                     1 year  887276361499
# 170                                    1 year  193905104062
# 91                                     1 year  884116361336
#
# [5 rows x 42 columns]

# %%
def handle_price(v):
    temp = v.split()
    price = temp[len(temp)-1][1:]
    price = price.replace(',','')
#     print(price)
    return price

# %%
df['Price__Price'] = df['Price__Price'].map(handle_price)
df['Price__Price'] = df['Price__Price'].astype(float)

# %% [markdown]
# ### 3. Convert Yes/No value to True/False and assign type = bool

# %% [markdown]
# Find all columns has two type of value

# %%
two_type_value_cols = []
for col in df.columns:
    if df[col].nunique() == 2:
        two_type_value_cols.append(col)
two_type_value_cols
# Out:
# ['Key Specs__Backlit Keyboard',
#  'Key Specs__Touch Screen',
#  'Feature__Backlit Keyboard',
#  'Display__Touch Screen',
#  'Included__Built-In Webcam',
#  'Certifications & Listings__ENERGY STAR Certified',
#  'Certifications & Listings__EPEAT Qualified']

# %% [markdown]
# Print col has two type of value

# %%
for col in two_type_value_cols:
    print("{} : {}".format(col, df[col].unique()))
# Out:
# Key Specs__Backlit Keyboard : ['No' 'Yes' nan]
# Key Specs__Touch Screen : ['No' 'Yes' nan]
# Feature__Backlit Keyboard : ['No' 'Yes' nan]
# Display__Touch Screen : ['No' 'Yes' nan]
# Included__Built-In Webcam : ['Yes' 'No' nan]
# Certifications & Listings__ENERGY STAR Certified : ['Yes' 'No' nan]
# Certifications & Listings__EPEAT Qualified : ['No' 'Yes' nan]

# %%
# Convert to bool type
for col in two_type_value_cols:
    df[col] = df[col].map(lambda x: True if x == "Yes" else False)
    df[col] = df[col].astype(bool)

# %% [markdown]
# ### 4. Normalize columns name

# %%
[str(v) for v in df.columns]
# Out:
# ['Price__Price',
#  'Key Specs__Backlit Keyboard',
#  'Key Specs__Screen Size',
#  'Key Specs__Touch Screen',
#  'Key Specs__Storage Type',
#  'Key Specs__System Memory (RAM)',
#  'Key Specs__Graphics',
#  'Key Specs__Processor Speed (Base)',
#  'Key Specs__Processor Model',
#  'Key Specs__Processor Model Number',
#  'Key Specs__Operating System',
#  'Key Specs__Battery Type',
#  'General__Product Name',
#  'General__Brand',
#  'General__Model Number',
#  'General__Color Category',
#  'Feature__Backlit Keyboard',
#  'Display__Screen Size',
#  'Display__Screen Resolution',
#  'Display__Touch Screen',
#  'Display__Display Type',
#  'Storage__Storage Type',
#  'Memory__System Memory (RAM)',
#  'Memory__Type of Memory (RAM)',
#  'Graphics__Graphics',
#  'Graphics__Graphics Type',
#  'Processor__Processor Brand',
#  'Processor__Processor Speed (Base)',
#  'Processor__Processor Model',
#  'Processor__Processor Model Number',
#  'Compatibility__Operating System',
#  'Included__Built-In Webcam',
#  'Included__Optical Drive Type',
#  'Power__Battery Type',
#  'Dimension__Product Height',
#  'Dimension__Product Width',
#  'Dimension__Product Depth',
#  'Certifications & Listings__ENERGY STAR Certified',
#  'Certifications & Listings__EPEAT Qualified',
#  "Warranty__Manufacturer's Warranty - Parts",
#  "Warranty__Manufacturer's Warranty - Labor",
#  'Other__UPC']

# %%
re_cols = [] # Prevent duplicate column name

for col in df.columns:
    new_col = str(col).split("__")[-1]
    if new_col not in re_cols:
        re_cols.append(new_col)
    else:
        re_cols.append(col)

re_cols
# Out:
# ['Price',
#  'Backlit Keyboard',
#  'Screen Size',
#  'Touch Screen',
#  'Storage Type',
#  'System Memory (RAM)',
#  'Graphics',
#  'Processor Speed (Base)',
#  'Processor Model',
#  'Processor Model Number',
#  'Operating System',
#  'Battery Type',
#  'Product Name',
#  'Brand',
#  'Model Number',
#  'Color Category',
#  'Feature__Backlit Keyboard',
#  'Display__Screen Size',
#  'Screen Resolution',
#  'Display__Touch Screen',
#  'Display Type',
#  'Storage__Storage Type',
#  'Memory__System Memory (RAM)',
#  'Type of Memory (RAM)',
#  'Graphics__Graphics',
#  'Graphics Type',
#  'Processor Brand',
#  'Processor__Processor Speed (Base)',
#  'Processor__Processor Model',
#  'Processor__Processor Model Number',
#  'Compatibility__Operating System',
#  'Built-In Webcam',
#  'Optical Drive Type',
#  'Power__Battery Type',
#  'Product Height',
#  'Product Width',
#  'Product Depth',
#  'ENERGY STAR Certified',
#  'EPEAT Qualified',
#  "Manufacturer's Warranty - Parts",
#  "Manufacturer's Warranty - Labor",
#  'UPC']

# %%
for i in range(len(re_cols)):
    new_cols[df.columns[i]] = re_cols[i]
df.rename(columns=new_cols, inplace=True)

# %% [markdown]
# # Save file

# %%
df.to_csv("../bestbuy.csv",index=False)

# %% [markdown]
# # Other

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041 entries, 0 to 1040
# Data columns (total 42 columns):
# Price                                1041 non-null float64
# Backlit Keyboard                     1041 non-null bool
# Screen Size                          1041 non-null object
# Touch Screen                         1041 non-null bool
# Storage Type                         1025 non-null object
# System Memory (RAM)                  1032 non-null object
# Graphics                             1012 non-null object
# Processor Speed (Base)               1002 non-null object
# Processor Model                      1041 non-null object
# Processor Model Number               1002 non-null object
# Operating System                     1027 non-null object
# Battery Type                         1041 non-null object
# Product Name                         1039 non-null object
# Brand                                1039 non-null object
# Model Number                         1041 non-null object
# Color Category                       1041 non-null object
# Feature__Backlit Keyboard            1041 non-null bool
# Display__Screen Size                 1041 non-null object
# Screen Resolution                    1039 non-null object
# Display__Touch Screen                1041 non-null bool
# Display Type                         1038 non-null object
# Storage__Storage Type                1025 non-null object
# Memory__System Memory (RAM)          1032 non-null object
# Type of Memory (RAM)                 1032 non-null object
# Graphics__Graphics                   1012 non-null object
# Graphics Type                        1031 non-null object
# Processor Brand                      1032 non-null object
# Processor__Processor Speed (Base)    1002 non-null object
# Processor__Processor Model           1032 non-null object
# Processor__Processor Model Number    1002 non-null object
# Compatibility__Operating System      1027 non-null object
# Built-In Webcam                      1041 non-null bool
# Optical Drive Type                   1004 non-null object
# Power__Battery Type                  1041 non-null object
# Product Height                       1008 non-null object
# Product Width                        1008 non-null object
# Product Depth                        1008 non-null object
# ENERGY STAR Certified                1041 non-null bool
# EPEAT Qualified                      1041 non-null bool
# Manufacturer's Warranty - Parts      1041 non-null object
# Manufacturer's Warranty - Labor      1041 non-null object
# UPC                                  1041 non-null int64
# dtypes: bool(7), float64(1), int64(1), object(33)
# memory usage: 291.9+ KB

# %%
#Quick Analysis on Dataset : DataTypes, Rows and Columns ,Null values, Unique values ...
def quick_analysis(df):
    print("Data Types:")
    print(df.dtypes)
    print("\nRows and Columns:")
    print(df.shape)
    print("\nColumn names:")
    print(df.columns)
    print("\nNull Values")
    print(df.apply(lambda x: sum(x.isnull()) / len(df)))
    print("\nUnique values")
    print(df.nunique())

quick_analysis(df)
# Out:
# Data Types:
# Price__Price                                         int64
# Key Specs__Backlit Keyboard                           bool
# Key Specs__Screen Size                              object
# Key Specs__Touch Screen                               bool
# Key Specs__Storage Type                             object
# Key Specs__System Memory (RAM)                      object
# Key Specs__Graphics                                 object
# Key Specs__Processor Speed (Base)                   object
# Key Specs__Processor Model                          object
# Key Specs__Processor Model Number                   object
# Key Specs__Operating System                         object
# Key Specs__Battery Type                             object
# General__Product Name                               object
# General__Brand                                      object
# General__Model Number                               object
# General__Color Category                             object
# Feature__Backlit Keyboard                             bool
# Display__Screen Size                                object
# Display__Screen Resolution                          object
# Display__Touch Screen                                 bool
# Display__Display Type                               object
# Storage__Storage Type                               object
# Memory__System Memory (RAM)                         object
# Memory__Type of Memory (RAM)                        object
# Graphics__Graphics                                  object
# Graphics__Graphics Type                             object
# Processor__Processor Brand                          object
# Processor__Processor Speed (Base)                   object
# Processor__Processor Model                          object
# Processor__Processor Model Number                   object
# Compatibility__Operating System                     object
# Included__Built-In Webcam                             bool
# Included__Optical Drive Type                        object
# Power__Battery Type                                 object
# Dimension__Product Height                           object
# Dimension__Product Width                            object
# Dimension__Product Depth                            object
# Certifications & Listings__ENERGY STAR Certified      bool
# Certifications & Listings__EPEAT Qualified            bool
# Warranty__Manufacturer's Warranty - Parts           object
# Warranty__Manufacturer's Warranty - Labor           object
# Other__UPC                                           int64
# dtype: object
#
# Rows and Columns:
# (1041, 42)
#
# Column names:
# Index(['Price__Price', 'Key Specs__Backlit Keyboard', 'Key Specs__Screen Size',
#        'Key Specs__Touch Screen', 'Key Specs__Storage Type',
#        'Key Specs__System Memory (RAM)', 'Key Specs__Graphics',
#        'Key Specs__Processor Speed (Base)', 'Key Specs__Processor Model',
#        'Key Specs__Processor Model Number', 'Key Specs__Operating System',
#        'Key Specs__Battery Type', 'General__Product Name', 'General__Brand',
#        'General__Model Number', 'General__Color Category',
#        'Feature__Backlit Keyboard', 'Display__Screen Size',
#        'Display__Screen Resolution', 'Display__Touch Screen',
#        'Display__Display Type', 'Storage__Storage Type',
#        'Memory__System Memory (RAM)', 'Memory__Type of Memory (RAM)',
#        'Graphics__Graphics', 'Graphics__Graphics Type',
#        'Processor__Processor Brand', 'Processor__Processor Speed (Base)',
#        'Processor__Processor Model', 'Processor__Processor Model Number',
#        'Compatibility__Operating System', 'Included__Built-In Webcam',
#        'Included__Optical Drive Type', 'Power__Battery Type',
#        'Dimension__Product Height', 'Dimension__Product Width',
#        'Dimension__Product Depth',
#        'Certifications & Listings__ENERGY STAR Certified',
#        'Certifications & Listings__EPEAT Qualified',
#        'Warranty__Manufacturer's Warranty - Parts',
#        'Warranty__Manufacturer's Warranty - Labor', 'Other__UPC'],
#       dtype='object')
#
# Null Values
# Price__Price                                        0.000000
# Key Specs__Backlit Keyboard                         0.000000
# Key Specs__Screen Size                              0.000000
# Key Specs__Touch Screen                             0.000000
# Key Specs__Storage Type                             0.015370
# Key Specs__System Memory (RAM)                      0.008646
# Key Specs__Graphics                                 0.027858
# Key Specs__Processor Speed (Base)                   0.037464
# Key Specs__Processor Model                          0.000000
# Key Specs__Processor Model Number                   0.037464
# Key Specs__Operating System                         0.013449
# Key Specs__Battery Type                             0.000000
# General__Product Name                               0.001921
# General__Brand                                      0.001921
# General__Model Number                               0.000000
# General__Color Category                             0.000000
# Feature__Backlit Keyboard                           0.000000
# Display__Screen Size                                0.000000
# Display__Screen Resolution                          0.001921
# Display__Touch Screen                               0.000000
# Display__Display Type                               0.002882
# Storage__Storage Type                               0.015370
# Memory__System Memory (RAM)                         0.008646
# Memory__Type of Memory (RAM)                        0.008646
# Graphics__Graphics                                  0.027858
# Graphics__Graphics Type                             0.009606
# Processor__Processor Brand                          0.008646
# Processor__Processor Speed (Base)                   0.037464
# Processor__Processor Model                          0.008646
# Processor__Processor Model Number                   0.037464
# Compatibility__Operating System                     0.013449
# Included__Built-In Webcam                           0.000000
# Included__Optical Drive Type                        0.035543
# Power__Battery Type                                 0.000000
# Dimension__Product Height                           0.031700
# Dimension__Product Width                            0.031700
# Dimension__Product Depth                            0.031700
# Certifications & Listings__ENERGY STAR Certified    0.000000
# Certifications & Listings__EPEAT Qualified          0.000000
# Warranty__Manufacturer's Warranty - Parts           0.000000
# Warranty__Manufacturer's Warranty - Labor           0.000000
# Other__UPC                                          0.000000
# dtype: float64
#
# Unique values
# Price__Price                                         434
# Key Specs__Backlit Keyboard                            2
# Key Specs__Screen Size                                21
# Key Specs__Touch Screen                                2
# Key Specs__Storage Type                                6
# Key Specs__System Memory (RAM)                         8
# Key Specs__Graphics                                   82
# Key Specs__Processor Speed (Base)                     34
# Key Specs__Processor Model                            56
# Key Specs__Processor Model Number                    165
# Key Specs__Operating System                           15
# Key Specs__Battery Type                                6
# General__Product Name                                897
# General__Brand                                        17
# General__Model Number                               1033
# General__Color Category                               13
# Feature__Backlit Keyboard                              2
# Display__Screen Size                                  21
# Display__Screen Resolution                            26
# Display__Touch Screen                                  2
# Display__Display Type                                 18
# Storage__Storage Type                                  6
# Memory__System Memory (RAM)                            8
# Memory__Type of Memory (RAM)                          11
# Graphics__Graphics                                    82
# Graphics__Graphics Type                                4
# Processor__Processor Brand                             5
# Processor__Processor Speed (Base)                     34
# Processor__Processor Model                            52
# Processor__Processor Model Number                    165
# Compatibility__Operating System                       15
# Included__Built-In Webcam                              2
# Included__Optical Drive Type                          17
# Power__Battery Type                                    6
# Dimension__Product Height                             62
# Dimension__Product Width                              81
# Dimension__Product Depth                             100
# Certifications & Listings__ENERGY STAR Certified       2
# Certifications & Listings__EPEAT Qualified             2
# Warranty__Manufacturer's Warranty - Parts             18
# Warranty__Manufacturer's Warranty - Labor             17
# Other__UPC                                          1039
# dtype: int64

# %% [markdown]
# # Mapping

# %%
fields_map = {'Price': ['Price__Price'],
'Screen Size': ['Display__Screen Size'],
'Processor': ['Performance__Processor Model'],
'RAM': ['Performance__System Memory (RAM)'],
'Hard Drive': ['Storage__Hard Drive RPM'],
'Operating System': ['Compatibility__Operating System Compatibility'],
'Color': ['General__Color Category'],
'Processor Brand': ['Performance__Processor Brand'],
'Hard Drive Interface': ['Storage__Hard Drive Interface'],
'Optical Drive Type': ['Included__Optical Drive Type'],
'Screen Resolution': ['Display__Screen Resolution'],
'Battery Type': ['Power__Battery Type'],
'Max Screen Resolution': ['Key Specs__Screen Resolution'],
'Graphics Coprocessor': ['Key Specs__Graphics'],
'Chipset Brand': ['Graphics__GPU Brand'],
'Card Description': ['Graphics__Graphics Type'],
'Wireless Type': [],
'Number of USB 2.0 Ports': ['Ports__Number of USB 2.0 Type A Ports','Ports__Number of USB 2.0 Type C Ports'],
'Number of USB 3.0 Ports': ['Ports__Number of USB 3.0 Type A Ports','Ports__Number of USB 3.0 Type C Ports','Ports__Number of USB 3.1 Type C Ports','Ports__Number of USB 3.1 Type A Ports'],
'Brand Name': ['General__Brand'],
'Series': ['General__Product Name'],
'Item model number': ['General__Model Number'],
'Item Weight': [],
'Product Dimensions': ['Dimension__Product Height', 'Dimension__Product Width', 'Dimension__Product Depth', 'Dimension__Product Weight'],
'Item Dimensions L x W x H': ['Dimension__Product Height', 'Dimension__Product Width', 'Dimension__Product Depth', 'Dimension__Product Weight'],
'Processor Count': ['Processor__Processor Brand', 'Processor__Processor Speed (Base)', 'Processor__Processor Model', 'Processor__Processor Model Number'],
'Computer Memory Type': ['Memory__Type of Memory (RAM)'],
'Flash Memory Size': ['Storage__Solid State Drive Capacity'],
'Hard Drive Rotational Speed': ['Storage__Hard Drive RPM'],
'Batteries': ['Power__Battery Type'],
'Average Battery Life (in hours)': ['Power__Battery Life/Key Specs__Battery Life'],
'Hardware Platform': [],
'Rear Webcam Resolution': ['Camera__Rear-Facing Camera','Camera__Rear Facing Camera Megapixels','Camera__Front Facing Camera Megapixels'],
'Power Source': [],
'Voltage': [],
'Memory Speed': ['Memory__System Memory RAM Speed'],
'California residents': [],
'Graphics Card Ram Size': ['Graphics__Video Memory'],
'National Stock Number': [],
'Package Dimensions': [],
'Audio-out Ports (#)': []
}

# %%
import json
maps = json.dumps(fields_map)
with open('../fields_map.json', 'w') as f:
    json.dump(fields_map, f)
